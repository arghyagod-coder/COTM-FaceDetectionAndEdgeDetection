# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
import os

for i in (os.listdir('monuments/')):
    img = cv.imread( f'monuments/{i}' , 0)
    img = cv.Canny(img, 100, 200)
    cv.imwrite(f"edged/edged_{i}.jpg", img)
